# %% [markdown]
# # 📊 Pandas EAD 1 - Introdução ao Pandas
#
# Este notebook é uma introdução à biblioteca **Pandas**, a ferramenta mais poderosa para análise de dados em Python.
#
# ## 📚 Conceitos abordados:
# - O que é o Pandas?
# - Instalação e importação
# - Estruturas principais: Series e DataFrame
# - Criando DataFrames
# - Visualizando dados
# - Selecionando colunas
# - Estatísticas básicas
#
# ## 🎯 Objetivo:
# Ao final deste módulo, você será capaz de criar e manipular DataFrames básicos no Pandas.
#
# **Vamos começar!** 🚀

# %% [markdown]
# ## 1. O que é o Pandas?
#
# Pandas é uma biblioteca Python que fornece estruturas de dados de alta performance e ferramentas de análise de dados.
#
# ### Principais estruturas:
#
# 1. **Series**: Array unidimensional (uma coluna)
# 2. **DataFrame**: Estrutura bidimensional (tabela com linhas e colunas)
#
# ### Por que usar Pandas?
# - ✅ Fácil manipulação de dados tabulares
# - ✅ Leitura/escrita de diversos formatos (CSV, Excel, SQL, JSON)
# - ✅ Limpeza e preparação de dados
# - ✅ Análise estatística rápida
# - ✅ Integração com outras bibliotecas (NumPy, Matplotlib)

# %% [markdown]
# ## 2. Instalação e Importação
#
# ### Instalação (se necessário):
# ```bash
# pip install pandas
# ```
#
# ### Importação:
# O padrão é importar o pandas como `pd`:

# %%
import pandas as pd

# Verificando a versão
print(f"Versão do Pandas: {pd.__version__}")
# Out:
# Versão do Pandas: 3.0.3

# %% [markdown]
# ## 3. Series - A Estrutura Unidimensional
#
# Uma Series é como uma coluna de dados. Pode ser criada a partir de uma lista, dicionário ou array NumPy.

# %%
# Criando uma Series a partir de uma lista
notas = pd.Series([8, 9, 7, 10, 6])
print(notas)
print("\n" + "="*40)
print(f"Média: {notas.mean()}")
print(f"Máximo: {notas.max()}")
print(f"Mínimo: {notas.min()}")
# Out:
# 0     8
# 1     9
# 2     7
# 3    10
# 4     6
# dtype: int64
#
# ...
# Média: 8.0
# Máximo: 10
# Mínimo: 6

# %% [markdown]
# ## 4. DataFrame - A Estrutura Bidimensional
#
# Um DataFrame é como uma planilha ou tabela SQL. É a estrutura mais usada no Pandas.

# %%
# Criando um DataFrame a partir de um dicionário
dados = {
    'Nome': ['Ana', 'João', 'Maria', 'Pedro', 'Carla'],
    'Idade': [25, 30, 28, 35, 22],
    'Cidade': ['São Paulo', 'Rio', 'Belo Horizonte', 'Curitiba', 'Salvador'],
    'Nota': [8.5, 9.0, 7.5, 9.5, 8.0]
}

df = pd.DataFrame(dados)
print(df)
# Out:
#     Nome  Idade          Cidade  Nota
# 0    Ana     25       São Paulo   8.5
# 1   João     30             Rio   9.0
# 2  Maria     28  Belo Horizonte   7.5
# 3  Pedro     35        Curitiba   9.5
# 4  Carla     22        Salvador   8.0

# %% [markdown]
# ## 5. Visualizando Dados
#
# O Pandas oferece várias formas de visualizar os dados:

# %%
# Visualizando as primeiras linhas
print("Primeiras 3 linhas:")
print(df.head(3))

print("\nÚltimas 2 linhas:")
print(df.tail(2))

print("\nInformações do DataFrame:")
print(df.info())

print("\nEstatísticas descritivas:")
print(df.describe())
# Out:
# Primeiras 3 linhas:
#     Nome  Idade          Cidade  Nota
# 0    Ana     25       São Paulo   8.5
# 1   João     30             Rio   9.0
# 2  Maria     28  Belo Horizonte   7.5
#
# Últimas 2 linhas:
#     Nome  Idade    Cidade  Nota
# 3  Pedro     35  Curitiba   9.5
# 4  Carla     22  Salvador   8.0
#
# Informações do DataFrame:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nome    5 non-null      str
#  1   Idade   5 non-null      int64
#  2   Cidade  5 non-null      str
#  3   Nota    5 non-null      float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 358.0 bytes
# None
#
# Estatísticas descritivas:
#            Idade      Nota
# count   5.000000  5.000000
# mean   28.000000  8.500000
# std     4.949747  0.790569
# min    22.000000  7.500000
# 25%    25.000000  8.000000
# 50%    28.000000  8.500000
# 75%    30.000000  9.000000
# ...

# %% [markdown]
# ## 6. Selecionando Colunas
#
# Você pode selecionar colunas de várias formas:

# %%
# Selecionando uma coluna (retorna uma Series)
print("Coluna Nome:")
print(df['Nome'])

print("\nMúltiplas colunas (retorna um DataFrame):")
print(df[['Nome', 'Nota']])
# Out:
# Coluna Nome:
# 0      Ana
# 1     João
# 2    Maria
# 3    Pedro
# 4    Carla
# Name: Nome, dtype: str
#
# Múltiplas colunas (retorna um DataFrame):
#     Nome  Nota
# 0    Ana   8.5
# 1   João   9.0
# 2  Maria   7.5
# 3  Pedro   9.5
# 4  Carla   8.0

# %% [markdown]
# ## 7. Adicionando Nova Coluna
#
# É muito fácil adicionar novas colunas a um DataFrame:

# %%
# Adicionando uma coluna de status (aprovado/reprovado)
df['Status'] = df['Nota'].apply(lambda x: 'Aprovado' if x >= 7 else 'Reprovado')
print(df)
# Out:
#     Nome  Idade          Cidade  Nota    Status
# 0    Ana     25       São Paulo   8.5  Aprovado
# 1   João     30             Rio   9.0  Aprovado
# 2  Maria     28  Belo Horizonte   7.5  Aprovado
# 3  Pedro     35        Curitiba   9.5  Aprovado
# 4  Carla     22        Salvador   8.0  Aprovado

# %% [markdown]
# ## 8. Exercícios - Nível 1
#
# Agora é sua vez! Resolva os exercícios abaixo para fixar os conceitos básicos do Pandas.

# %% [markdown]
# ### Exercício 1: Criando um DataFrame
# Crie um DataFrame com os seguintes dados de produtos:
# - Produtos: ['Notebook', 'Mouse', 'Teclado', 'Monitor', 'Headset']
# - Preços: [2500, 80, 200, 1200, 300]
# - Quantidade: [10, 50, 30, 15, 40]
#
# Calcule o valor total em estoque (preço * quantidade) para cada produto e adicione como uma nova coluna.

# %%
# Seu código aqui
import pandas as pd

x = {
    'Produtos': ['Notebook', 'Mouse', 'Teclado', 'Monitor', 'Headset'],
    'Preços': [2500, 80, 200, 1200, 300],
    'Quantidade': [10, 50, 30, 15, 40]
}

df = pd.DataFrame(x)

df['Valor_total'] = df['Preços'] * df['Quantidade']

print(df)
# Out:
#    Produtos  Preços  Quantidade  Valor_total
# 0  Notebook    2500          10        25000
# 1     Mouse      80          50         4000
# 2   Teclado     200          30         6000
# 3   Monitor    1200          15        18000
# 4   Headset     300          40        12000

# %% [markdown]
# ### Exercício 2: Visualizando Dados
# Use o DataFrame criado no exercício anterior e:
# 1. Mostre as 3 primeiras linhas
# 2. Mostre as estatísticas descritivas
# 3. Mostre apenas os produtos com preço > 500

# %%
# Seu código aqui

print(df.head(3))
print(df.describe())
print(df[df['Preços'] > 500])
# Out:
#    Produtos  Preços  Quantidade  Valor_total
# 0  Notebook    2500          10        25000
# 1     Mouse      80          50         4000
# 2   Teclado     200          30         6000
#             Preços  Quantidade   Valor_total
# count     5.000000    5.000000      5.000000
# mean    856.000000   29.000000  13000.000000
# std    1020.137246   16.733201   8660.254038
# min      80.000000   10.000000   4000.000000
# 25%     200.000000   15.000000   6000.000000
# 50%     300.000000   30.000000  12000.000000
# 75%    1200.000000   40.000000  18000.000000
# max    2500.000000   50.000000  25000.000000
#    Produtos  Preços  Quantidade  Valor_total
# 0  Notebook    2500          10        25000
# 3   Monitor    1200          15        18000

# %% [markdown]
# ### Exercício 3: Series e Métodos Básicos
# Crie uma Series com as idades de 10 pessoas. Calcule e imprima:
# - Média das idades
# - Mediana
# - Desvio padrão
# - Idade máxima e mínima
# - Número total de elementos

# %%
# Seu código aqui
import pandas as pd

idades = pd.Series([15, 18, 20, 22, 25, 30, 35, 40, 45, 50])

print("Média das idades:", idades.mean())
print("Mediana:", idades.median())
print("Desvio padrão:", idades.std())
print("Idade máxima:", idades.max())
print("Idade mínima:", idades.min())
print("Número total de elementos:", idades.count())
# Out:
# Média das idades: 30.0
# Mediana: 27.5
# Desvio padrão: 12.055427546683417
# Idade máxima: 50
# Idade mínima: 15
# Número total de elementos: 10

# %% [markdown]
# ### Exercício 4: DataFrame a partir de Lista
# Crie um DataFrame a partir de uma lista de listas:
# ```python
# dados = [
#     ['Ana', 25, 'SP', 8.5],
#     ['João', 30, 'RJ', 9.0],
#     ['Maria', 28, 'BH', 7.5]
# ]
# ```
# Defina os nomes das colunas como ['Nome', 'Idade', 'Cidade', 'Nota'].

# %%
# Seu código aqui
import pandas as pd

dados = [
    ['Ana', 25, 'SP', 8.5],
    ['João', 30, 'RJ', 9.0],
    ['Maria', 28, 'BH', 7.5]
]

df = pd.DataFrame(dados, columns=['Nome', 'Idade', 'Cidade', 'Nota'])

print(df)
# Out:
#     Nome  Idade Cidade  Nota
# 0    Ana     25     SP   8.5
# 1   João     30     RJ   9.0
# 2  Maria     28     BH   7.5

# %% [markdown]
# ### Exercício 5: Adicionando Colunas
# Baseado no DataFrame do exercício 4, adicione:
# 1. Uma coluna 'Dobro da Idade'
# 2. Uma coluna 'Nota + 1'

# %%
# Seu código aqui]
import pandas as pd

dados = [
    ['Ana', 25, 'SP', 8.5],
    ['João', 30, 'RJ', 9.0],
    ['Maria', 28, 'BH', 7.5]
]

df = pd.DataFrame(dados, columns=['Nome', 'Idade', 'Cidade', 'Nota'])

df['Dobro da Idade'] = df['Idade'] * 2
df['Nota + 1'] = df['Nota'] + 1

print(df)
# Out:
#     Nome  Idade Cidade  Nota  Dobro da Idade  Nota + 1
# 0    Ana     25     SP   8.5              50       9.5
# 1   João     30     RJ   9.0              60      10.0
# 2  Maria     28     BH   7.5              56       8.5
